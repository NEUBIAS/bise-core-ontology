# %%
import json
import io

from rdflib import ConjunctiveGraph, RDFS, Namespace, URIRef, BNode, Literal
from rdflib.namespace import RDF

#import networkx as nx
#from nxpd import draw

g = ConjunctiveGraph()
g.bind('prov', Namespace('http://www.w3.org/ns/prov#'))
g.bind('p-plan', Namespace('http://purl.org/net/p-plan#'))
g.bind('dc', Namespace('http://dcterms/'))
g.bind('nb-core', Namespace('http://bise-eu.info/core-ontology#'))

nb_core = Namespace("http://bise-eu.info/core-ontology#")
pplan = Namespace("http://purl.org/net/p-plan#")
bise = Namespace("http://biii.eu/node/")

# %% [markdown]
# # 1. Load the EDAM Bioimaging ontology

# %%
def load_rdf(filename):
    with io.open(filename,'r',encoding='utf8') as f:
        g.load(f, format='turtle')  
        
def load_remote_rdf(url):
    g.load(url, format='turtle')
    
def load_remote_owl(url):
    g.load(url, format='xml')


def load_owl(filename):
    with io.open(filename,'r',encoding='utf8') as f:
        g.load(f, format='xml')  

#with open('test.json', 'r') as data_file:
#    data_str = data_file.read()
#try:
#    data = json.loads(data_str)
#except json.decoder.JSONDecodeError as e:
#    print("parsing ERROR "+e.msg)

#import requests
#r = requests.get('http://test.biii.eu/wfsteps?_format=json') 
#print(json.dumps(r.json(), indent=4))
#data = r.json()

#load_remote_rdf('https://raw.githubusercontent.com/NeuBIAS/bise-core-ontology/master/data-dumps/latest/neubias-latest.ttl')
#load_owl('./bise-linked-data-webapp/static/data/EDAM-bioimaging_alpha03.owl')
load_remote_owl('https://github.com/edamontology/edam-bioimaging/raw/master/releases/EDAM-bioimaging_alpha06.owl')

# %% [markdown]
# # 2. Indexing all synonyms and labels associated to EDAM concepts

# %%
import pandas as pd

synonyms_query = """
    SELECT ?edam_class ?label ?related_syn ?narrow_syn ?exact_syn ?broad_syn WHERE {
        # ?edam_class rdfs:label ?label .
        OPTIONAL {?edam_class oboInOwl:hasRelatedSynonym ?related_syn .}
        OPTIONAL {?edam_class oboInOwl:hasNarrowSynonym ?narrow_syn .}
        OPTIONAL {?edam_class oboInOwl:hasExactSynonym ?exact_syn .}
        OPTIONAL {?edam_class oboInOwl:hasBroadSynonym ?broad_syn .}
    } 
"""

labels_index = {}
exact_syn_index = {}
narrow_syn_index = {}
broad_syn_index = {}
related_syn_index = {}

edam_syn_index = {}

results = g.query(synonyms_query)

for r in results :
#    print(r)
    if r['label']:
        labels_index[str(r['label'])] = str(r['edam_class'])
        edam_syn_index[str(r['label'])] = {'uri': str(r['edam_class'])}
    
    if r['exact_syn']:
        exact_syn_index[str(r['exact_syn'])] = str(r['edam_class'])
        
        if 'exact_syn' not in edam_syn_index[str(r['label'])].keys():
            edam_syn_index[str(r['label'])]['exact_syn'] = [str(r['exact_syn'])]
        else:
            edam_syn_index[str(r['label'])]['exact_syn'].append(str(r['exact_syn']))
        
    if r['narrow_syn']:
        narrow_syn_index[str(r['narrow_syn'])] = str(r['edam_class'])
        
        if 'narrow_syn' not in edam_syn_index[str(r['label'])].keys():
            edam_syn_index[str(r['label'])]['narrow_syn'] = [str(r['narrow_syn'])]
        else:
            edam_syn_index[str(r['label'])]['narrow_syn'].append(str(r['narrow_syn']))
            
    if r['broad_syn']:
        broad_syn_index[str(r['broad_syn'])] = str(r['edam_class'])
        
        if 'broad_syn' not in edam_syn_index[str(r['label'])].keys():
            edam_syn_index[str(r['label'])]['broad_syn'] = [str(r['broad_syn'])]
        else:
            edam_syn_index[str(r['label'])]['broad_syn'].append(str(r['broad_syn']))
            
    if r['related_syn']:
        related_syn_index[str(r['related_syn'])] = str(r['edam_class'])
        
        if 'related_syn' not in edam_syn_index[str(r['label'])].keys():
            edam_syn_index[str(r['label'])]['related_syn'] = [str(r['related_syn'])]
        else:
            edam_syn_index[str(r['label'])]['related_syn'].append(str(r['related_syn']))
            
print(json.dumps(edam_syn_index, indent=4))
# Out:
# {
#     "Geometric distortion correction": {
#         "uri": "http://edamontology.org/operation__R3BGvVm77d5vFMF6f28ZiW",
#         "narrow_syn": [
#             "Lens distortion correction"
#         ]
#     },
#     "Electron cryotomography": {
#         "uri": "http://edamontology.org/topic__RDCjx86atJP685sX1zrE2ia",
#         "exact_syn": [
#             "CryoET"
#         ],
#         "narrow_syn": [
#             "CET"
#         ],
#         "broad_syn": [
#             "CryoTEM"
#         ]
#     },
#     "Binary format": {
#         "uri": "http://edamontology.org/format_Binary_format"
#     },
#     "Smoothing": {
#         "uri": "http://edamontology.org/operation_Image_smoothing",
#         "narrow_syn": [
#             "Gaussian filtering"
#         ],
#         "related_syn": [
#             "Blurring"
#         ]
#     },
#     "Serial block-face scanning electron microscopy": {
#         "uri": "http://edamontology.org/topic__RByvmgDpAo4FOrMdvTm1gwR",
#         "exact_syn": [
#             "SBF SEM"
#         ],
#         "narrow_syn": [
#             "3View\u00ae"
#         ]
#     },
#     "Live sample imaging": {
#         "uri": "http://edamontology.org/topic__RL4rPCXlIu9uzNrGcbcSNp",
#         "broad_syn": [
#             "Dynamic imaging"
#         ]
#     },
#     "Light-sheet microscopy": {
#         "uri": "http://edamontology.org/topic_Light-sheet_microscopy",
#         "narrow_syn": [
#             "Swept confocally-aligned planar excitation microscopy (SCAPE)"
#         ],
#         "related_syn": [
#             "Bessel Beam Lightsheet Microscopy"
#         ]
#     },
#     "Fourier-transform infrared spectroscopy": {
#         "uri": "http://edamontology.org/topic______Fourier-transform_infrared_spectroscopy",
#         "exact_syn": [
#             "FTIR"
#         ]
#     },
#     "Model-based segmentation": {
#         "uri": "http://edamontology.org/operation____Model-based_segmentation"
#     },
#     "Image analysis": {
#         "uri": "http://edamontology.org/operation_3443",
#         "narrow_syn": [
#             "General image analysis"
#         ]
#     },
#     "DIC microscopy": {
#         "uri": "http://edamontology.org/topic__RNFOzq5E0ZVBh5Euhn06rn",
#         "exact_syn": [
#             "Differential interference contrast microscopy"
#         ],
#         "narrow_syn": [
#             "Nomarski interferential contrast (NIC)"
#         ]
#     },
#     "is identifier of": {
#         "uri": "http://edamontology.org/is_identifier_of"
#     },
#     "Volume rendering": {
#         "uri": "http://edamontology.org/operation_Volume_rendering"
#     },
#     "Image correction": {
#         "uri": "http://edamontology.org/operation__R7MFwdgojfmkZ07yWbdcda0",
#         "narrow_syn": [
#             "Instrument aberration correction"
#         ],
#         "related_syn": [
#             "Image preprocessing"
#         ]
#     },
#     "Pixel classification": {
#         "uri": "http://edamontology.org/operation_Pixel_classification",
#         "exact_syn": [
#             "Pixel labeling"
#         ],
#         "narrow_syn": [
#             "Semantic image segmentation"
#         ]
#     },
#     "Image bit depth": {
#         "uri": "http://edamontology.org/data__RDcwcMJia2DgGNXx2JKa8Oc"
#     },
#     "Dark-field microscopy": {
#         "uri": "http://edamontology.org/topic__R89wYXZ2735GXdn4m4GOT9n"
#     },
#     "Intravital imaging": {
#         "uri": "http://edamontology.org/topic_____Intravital_imaging"
#     },
#     "Connected-component analysis": {
#         "uri": "http://edamontology.org/operation_____Connected-component_analysis"
#     },
#     "Tomography": {
#         "uri": "http://edamontology.org/topic_3452"
#     },
#     "Object detection": {
#         "uri": "http://edamontology.org/operation__RBNng13hEB0CJD5VzSKqrfB",
#         "narrow_syn": [
#             "Object localisation"
#         ]
#     },
#     "Affine registration": {
#         "uri": "http://edamontology.org/operation__RLtOI0poPsYRHzgXbAcr2E",
#         "exact_syn": [
#             "Affine image registration"
#         ]
#     },
#     "Ex-vivo imaging": {
#         "uri": "http://edamontology.org/topic__RB4unXFUWvdBe91ihVAA9rR"
#     },
#     "Conversion": {
#         "uri": "http://edamontology.org/operation_3434"
#     },
#     "Adaptive microscopy": {
#         "uri": "http://edamontology.org/topic______Self-adjusting_microscopy",
#         "narrow_syn": [
#             "Intelligent microscopy"
#         ]
#     },
#     "Object tracking": {
#         "uri": "http://edamontology.org/operation_Image_tracking",
#         "exact_syn": [
#             "Tracking"
#         ],
#         "narrow_syn": [
#             "Trajectory extraction"
#         ]
#     },
#     "Image generation": {
#         "uri": "http://edamontology.org/operation__RDFFD5jBfUw74a3vJeBAGB1",
#         "exact_syn": [
#             "Image synthesis"
#         ]
#     },
#     "has output": {
#         "uri": "http://edamontology.org/has_output",
#         "related_syn": [
#             "OBO_REL:has_participant"
#         ]
#     },
#     "Confocal fluorescence microscopy": {
#         "uri": "http://edamontology.org/topic__Rn8MnorStmqIkNlAVZWBc0",
#         "narrow_syn": [
#             "Laser scanning microscopy (LSM)"
#         ]
#     },
#     "Landmark assignment": {
#         "uri": "http://edamontology.org/operation__RDggamr21qZlMqkQmyOdC7l",
#         "exact_syn": [
#             "Reference point assignment"
#         ],
#         "narrow_syn": [
#             "Fiducial placement"
#         ]
#     },
#     "Image time series": {
#         "uri": "http://edamontology.org/data__RCMgLYJyn9WJyCc3bA23xT1",
#         "exact_syn": [
#             "Time-series image"
#         ],
#         "narrow_syn": [
#             "Video sequence"
#         ]
#     },
#     "hdf5": {
#         "uri": "http://edamontology.org/format_hdf5",
#         "exact_syn": [
#             "h5"
#         ]
#     },
#     "Hide in subset": {
#         "uri": "http://edamontology.org/hide_in_subset"
#     },
#     "Tomographic reconstruction": {
#         "uri": "http://edamontology.org/operation__R1NVO6hpWWcs99UiEFiOfK",
#         "exact_syn": [
#             "Tomography reconstruction"
#         ],
#         "narrow_syn": [
#             "Filtered back projection"
#         ]
#     },
#     "Scientific visualisation": {
#         "uri": "http://edamontology.org/topic______Scientific_visualisation",
#         "exact_syn": [
#             "Scientific visualization"
#         ],
#         "narrow_syn": [
#             "Interactive visual analysis"
#         ]
#     },
#     "dat": {
#         "uri": "http://edamontology.org/format_dat",
#         "exact_syn": [
#             ".dat"
#         ]
#     },
#     "Object feature extraction": {
#         "uri": "http://edamontology.org/operation_Feature_extraction",
#         "exact_syn": [
#             "Feature detection"
#         ],
#         "narrow_syn": [
#             "scale-invariant feature transform"
#         ]
#     },
#     "Documentation": {
#         "uri": "http://edamontology.org/documentation",
#         "related_syn": [
#             "Specification"
#         ]
#     },
#     "Digital pathology": {
#         "uri": "http://edamontology.org/topic_____Digital_pathology",
#         "narrow_syn": [
#             "Digital histopathology"
#         ],
#         "related_syn": [
#             "Telepathology"
#         ]
#     },
#     "Regular expression": {
#         "uri": "http://edamontology.org/regex"
#     },
#     "X-ray microscopy": {
#         "uri": "http://edamontology.org/topic_____X-ray_microscopy"
#     },
#     "Image processing": {
#         "uri": "http://edamontology.org/operation_Image_processing",
#         "exact_syn": [
#             "Image transformation"
#         ],
#         "narrow_syn": [
#             "Image postprocessing"
#         ],
#         "related_syn": [
#             "Image manipulation"
#         ]
#     },
#     "Plunge freezing": {
#         "uri": "http://edamontology.org/topic__RMctC69gGv9qYqwKCXxeLF"
#     },
#     "Phase imaging": {
#         "uri": "http://edamontology.org/topic______Phase_imaging",
#         "narrow_syn": [
#             "Ptychography"
#         ]
#     },
#     "Image annotation": {
#         "uri": "http://edamontology.org/operation_3553"
#     },
#     "Single-photon emission computed tomography": {
#         "uri": "http://edamontology.org/topic__RBkRgSi7js0c70kjiPgYTgR",
#         "related_syn": [
#             "SPECT"
#         ]
#     },
#     "Expansion microscopy": {
#         "uri": "http://edamontology.org/topic_____Expansion_microscopy",
#         "exact_syn": [
#             "ExM"
#         ]
#     },
#     "Texture extraction": {
#         "uri": "http://edamontology.org/operation_Texture_extraction",
#         "exact_syn": [
#             "Texture feature extraction"
#         ],
#         "narrow_syn": [
#             "Inverse Difference Moment"
#         ]
#     },
#     "Dense image annotation": {
#         "uri": "http://edamontology.org/operation______Dense_annotation"
#     },
#     "Sample clearing": {
#         "uri": "http://edamontology.org/topic______Sample_clearing",
#         "narrow_syn": [
#             "cleared tissue"
#         ]
#     },
#     "is output of": {
#         "uri": "http://edamontology.org/is_output_of",
#         "related_syn": [
#             "OBO_REL:participates_in"
#         ]
#     },
#     "Media type": {
#         "uri": "http://edamontology.org/media_type",
#         "narrow_syn": [
#             "MIME type"
#         ]
#     },
#     "Evolutionary algorithm": {
#         "uri": "http://edamontology.org/topic______Evolutionary_algorithm",
#         "narrow_syn": [
#             "Genetic algorithm"
#         ]
#     },
#     "Photoablation": {
#         "uri": "http://edamontology.org/topic______Photoablation",
#         "narrow_syn": [
#             "Laser ablation"
#         ]
#     },
#     "Editing": {
#         "uri": "http://edamontology.org/operation_3096"
#     },
#     "Image characteristics": {
#         "uri": "http://edamontology.org/data__R80aNLt4YY02ByptWQa2yrY",
#         "related_syn": [
#             "Image metadata"
#         ]
#     },
#     "Cell lineage extraction": {
#         "uri": "http://edamontology.org/operation_____Cell_lineage_extraction"
#     },
#     "Imaging flow cytometry": {
#         "uri": "http://edamontology.org/topic______Imaging_flow_cytometry",
#         "exact_syn": [
#             "IFC"
#         ]
#     },
#     "Array tomography": {
#         "uri": "http://edamontology.org/topic_____Array_tomography"
#     },
#     "Spatial image resolution": {
#         "uri": "http://edamontology.org/data__R9yc0jq1eJBgmvEQwMcRSUS"
#     },
#     "Radiometric properties": {
#         "uri": "http://edamontology.org/data__RCjZhkavxxifpvdNiasVVCc"
#     },
#     "Transmission light microscopy": {
#         "uri": "http://edamontology.org/topic__R9P5gEAm1wic4R2PcZ7ZpPA",
#         "narrow_syn": [
#             "Widefield transmission light microscopy"
#         ]
#     },
#     "Bioluminescence imaging": {
#         "uri": "http://edamontology.org/topic__RDvZSyRAcr8fonKvKdVoXw2",
#         "exact_syn": [
#             "BLI"
#         ]
#     },
#     "Laser microdissection": {
#         "uri": "http://edamontology.org/topic______Laser_microdissection",
#         "narrow_syn": [
#             "Laser capture microdissection (LCM)"
#         ]
#     },
#     "Overlay": {
#         "uri": "http://edamontology.org/operation_Overlay"
#     },
#     "Image reconstruction": {
#         "uri": "http://edamontology.org/operation_Image_reconstruction",
#         "narrow_syn": [
#             "Image restoration"
#         ]
#     },
#     "Edge detection": {
#         "uri": "http://edamontology.org/operation____Edge_detection"
#     },
#     "Localisation markers": {
#         "uri": "http://edamontology.org/topic_____Fiducial_markers",
#         "exact_syn": [
#             "Landmarks"
#         ],
#         "narrow_syn": [
#             "Localisation beads"
#         ],
#         "related_syn": [
#             "Finder grids"
#         ]
#     },
#     "Distribution-based clustering": {
#         "uri": "http://edamontology.org/operation______Distribution-based_clustering"
#     },
#     "Image registration": {
#         "uri": "http://edamontology.org/operation_Image_registration",
#         "exact_syn": [
#             "Image alignment"
#         ]
#     },
#     "k-nearest neighbours": {
#         "uri": "http://edamontology.org/topic______k-nearest_neighbours",
#         "exact_syn": [
#             "k-NN"
#         ]
#     },
#     "Operation": {
#         "uri": "http://edamontology.org/operation_0004",
#         "narrow_syn": [
#             "Computational procedure"
#         ],
#         "broad_syn": [
#             "Function"
#         ],
#         "related_syn": [
#             "sumo:Function"
#         ]
#     },
#     "Sample embedding": {
#         "uri": "http://edamontology.org/topic______Sample_embedding"
#     },
#     "Frequency-domain analysis": {
#         "uri": "http://edamontology.org/operation__RBYLqCqN4rP7Jy5m5mxpTeM",
#         "exact_syn": [
#             "Analysis in the frequency domain"
#         ],
#         "related_syn": [
#             "Wavelet transform"
#         ]
#     },
#     "Image enhancement": {
#         "uri": "http://edamontology.org/operation_Image_enhancement",
#         "narrow_syn": [
#             "Image restoration"
#         ]
#     },
#     "Time-lapse data": {
#         "uri": "http://edamontology.org/data_Time-lapse_data"
#     },
#     "2D image": {
#         "uri": "http://edamontology.org/data_2D_dataset"
#     },
#     "Artificial intelligence": {
#         "uri": "http://edamontology.org/topic______Artificial_intelligence",
#         "exact_syn": [
#             "AI"
#         ]
#     },
#     "Multi-photon microscopy": {
#         "uri": "http://edamontology.org/topic__RBKlmE9DGTZwEwxw0juThGg",
#         "narrow_syn": [
#             "Three-photon excitation microscopy"
#         ]
#     },
#     "Support vector machine": {
#         "uri": "http://edamontology.org/topic______Support_vector_machine",
#         "exact_syn": [
#             "SVM"
#         ]
#     },
#     "Fluorescence recovery after photobleaching": {
#         "uri": "http://edamontology.org/topic___Fluorescence_recovery_after_photobleaching",
#         "exact_syn": [
#             "FRAP"
#         ],
#         "related_syn": [
#             "Inverse fluorescence recovery after photobleaching (iFRAP)"
#         ]
#     },
#     "is format of": {
#         "uri": "http://edamontology.org/is_format_of",
#         "related_syn": [
#             "OBO_REL:quality_of"
#         ]
#     },
#     "Alignment construction": {
#         "uri": "http://edamontology.org/operation_2928"
#     },
#     "Instrument distortion characteristics": {
#         "uri": "http://edamontology.org/data____Instrument_distortion_characteristics",
#         "exact_syn": [
#             "Lens distortion characteristics"
#         ]
#     },
#     "Warping": {
#         "uri": "http://edamontology.org/operation_Warping"
#     },
#     "Stereoscopy": {
#         "uri": "http://edamontology.org/topic______Stereoscopy",
#         "narrow_syn": [
#             "Stereoscopics"
#         ]
#     },
#     "Decision tree": {
#         "uri": "http://edamontology.org/topic______Decision_tree",
#         "exact_syn": [
#             "Decision tree learning"
#         ]
#     },
#     "Optical projection tomography": {
#         "uri": "http://edamontology.org/topic______Optical_Projection_Tomography",
#         "exact_syn": [
#             "Optical tomography"
#         ],
#         "narrow_syn": [
#             "optical-ECT"
#         ]
#     },
#     "Created in": {
#         "uri": "http://edamontology.org/created_in"
#     },
#     "Volume": {
#         "uri": "http://edamontology.org/data_Volume"
#     },
#     "Image data properties": {
#         "uri": "http://edamontology.org/data_Image_geometry"
#     },
#     "Atomic force microscopy": {
#         "uri": "http://edamontology.org/topic_____Atomic_force_microscopy",
#         "exact_syn": [
#             "AFM"
#         ],
#         "narrow_syn": [
#             "Scanning force microscopy"
#         ]
#     },
#     "Single molecule localisation": {
#         "uri": "http://edamontology.org/operation__R8EfungVXA0oQM2Ac7YY5eu",
#         "exact_syn": [
#             "Single molecule localization"
#         ],
#         "narrow_syn": [
#             "STORM image reconstruction"
#         ]
#     },
#     "Bright-field microscopy": {
#         "uri": "http://edamontology.org/topic__RDdX0TswBVhmWiS1dI3pghN"
#     },
#     "Supervised learning": {
#         "uri": "http://edamontology.org/topic___Supervised_learning"
#     },
#     "Ultrasonography": {
#         "uri": "http://edamontology.org/topic__RBHw300pzIYcttGsAmIZvk5",
#         "exact_syn": [
#             "diagnostic sonography"
#         ],
#         "narrow_syn": [
#             "Ultrasound imaging"
#         ]
#     },
#     "Plant image analysis": {
#         "uri": "http://edamontology.org/topic_____Plant_image_analysis",
#         "broad_syn": [
#             "Plant image informatics"
#         ]
#     },
#     "Sample preparation": {
#         "uri": "http://edamontology.org/topic__ReQzVVVh0IPyN0c1V5wQVO"
#     },
#     "Greyscale": {
#         "uri": "http://edamontology.org/data_Greyscale"
#     },
#     "Microtomy": {
#         "uri": "http://edamontology.org/topic______Microtomy",
#         "narrow_syn": [
#             "Ultra-microtomy"
#         ]
#     },
#     "Region-proposal network": {
#         "uri": "http://edamontology.org/topic______Region-proposal_network",
#         "exact_syn": [
#             "RBF network"
#         ]
#     },
#     "Feature enhancement": {
#         "uri": "http://edamontology.org/operation_Edge_detection",
#         "narrow_syn": [
#             "Edge enhancement"
#         ]
#     },
#     "Manual segmentation": {
#         "uri": "http://edamontology.org/operation______Manual_segmentation"
#     },
#     "Pixel-based colocalisation analysis": {
#         "uri": "http://edamontology.org/operation___Pixel-based_colocalisation",
#         "exact_syn": [
#             "Pixel-based colocalization analysis"
#         ]
#     },
#     "Fluorescence lifetime imaging microscopy": {
#         "uri": "http://edamontology.org/topic___Fluorescence_lifetime_imaging",
#         "exact_syn": [
#             "FLIM"
#         ]
#     },
#     "Analysis": {
#         "uri": "http://edamontology.org/operation_2945"
#     },
#     "Light field microscopy": {
#         "uri": "http://edamontology.org/topic_____Light_field_microscopy"
#     },
#     "Airyscan": {
#         "uri": "http://edamontology.org/topic______Airyscan"
#     },
#     "Image segmentation": {
#         "uri": "http://edamontology.org/operation_Image_segmentation"
#     },
#     "Medical imaging": {
#         "uri": "http://edamontology.org/topic______Medical_imaging"
#     },
#     "Sample thinning": {
#         "uri": "http://edamontology.org/topic______Sample_thinning"
#     },
#     "Montage": {
#         "uri": "http://edamontology.org/operation_Montage"
#     },
#     "Geometrical transformation": {
#         "uri": "http://edamontology.org/operation_Geometrical_transform"
#     },
#     "Sparse image annotation": {
#         "uri": "http://edamontology.org/operation______Sparse_annotation"
#     },
#     "Temporal properties": {
#         "uri": "http://edamontology.org/data__R7sy3JByrUsyKaGNYQ1eSQF"
#     },
#     "Machine learning": {
#         "uri": "http://edamontology.org/topic_3474",
#         "exact_syn": [
#             "ML"
#         ],
#         "narrow_syn": [
#             "Statistical learning"
#         ],
#         "related_syn": [
#             "Data mining"
#         ]
#     },
#     "Trajectory analysis": {
#         "uri": "http://edamontology.org/operation___Trajectory_analysis",
#         "related_syn": [
#             "Displacement analysis"
#         ]
#     },
#     "Superpixel extraction": {
#         "uri": "http://edamontology.org/operation_____Superpixel_extraction",
#         "exact_syn": [
#             "Supervoxel extraction"
#         ]
#     },
#     "Wound-healing analysis": {
#         "uri": "http://edamontology.org/operation___Wound-healing_analysis"
#     },
#     "Neuron image analysis": {
#         "uri": "http://edamontology.org/topic_Neuron_image_analysis",
#         "narrow_syn": [
#             "Connectomics"
#         ],
#         "broad_syn": [
#             "Neuron image informatics"
#         ]
#     },
#     "Natural language processing": {
#         "uri": "http://edamontology.org/topic_0218"
#     },
#     "Photoacoustic tomography": {
#         "uri": "http://edamontology.org/topic__R9WwNqEL8rvkyBPk7GkDTYh",
#         "exact_syn": [
#             "PAT"
#         ],
#         "broad_syn": [
#             "Photoacoustic imaging"
#         ]
#     },
#     "Bayesian statistics": {
#         "uri": "http://edamontology.org/topic______Bayesian_statistics"
#     },
#     "In-silico reconstruction": {
#         "uri": "http://edamontology.org/topic__R96toeNl9iMp8oqv9augU84",
#         "broad_syn": [
#             "3D reconstruction"
#         ]
#     },
#     "Freeze fracturing": {
#         "uri": "http://edamontology.org/topic__RbM6PZFI9i5lG4gzAySn0c",
#         "exact_syn": [
#             "Freeze-fracture"
#         ]
#     },
#     "Optical sectioning tomography": {
#         "uri": "http://edamontology.org/topic_____Micro-optical_sectioning_tomography",
#         "narrow_syn": [
#             "Two-photon micro-optical sectioning microscopy"
#         ]
#     },
#     "img": {
#         "uri": "http://edamontology.org/format_img",
#         "exact_syn": [
#             ".img"
#         ]
#     },
#     "Cryofixation": {
#         "uri": "http://edamontology.org/topic__R77vfEkRqjIenYUqhDPvdkM",
#         "exact_syn": [
#             "Cryo-fixation"
#         ]
#     },
#     "Region properties": {
#         "uri": "http://edamontology.org/data__RCRp3XI62rYeU9aZHw4yBvj"
#     },
#     "Soft X-ray tomography": {
#         "uri": "http://edamontology.org/topic_____Soft_x-ray_tomography",
#         "exact_syn": [
#             "SXT"
#         ],
#         "narrow_syn": [
#             "Cryo-SXT"
#         ]
#     },
#     "Collective object tracking": {
#         "uri": "http://edamontology.org/operation__RBUpi1JSczmHQSf8Q8fDzG5",
#         "related_syn": [
#             "Scratch assay"
#         ]
#     },
#     "has function": {
#         "uri": "http://edamontology.org/has_function",
#         "related_syn": [
#             "OBO_REL:bearer_of"
#         ]
#     },
#     "Intensity-based registration": {
#         "uri": "http://edamontology.org/operation_____Intensity-based_registration",
#         "narrow_syn": [
#             "Area-based registration"
#         ]
#     },
#     "nD image": {
#         "uri": "http://edamontology.org/data_4D_dataset"
#     },
#     "Critical-point drying": {
#         "uri": "http://edamontology.org/topic__R9PtYz3fOHhRsnKnQzFIXff",
#         "exact_syn": [
#             "CPD"
#         ]
#     },
#     "Random forest": {
#         "uri": "http://edamontology.org/topic______Random_forest",
#         "exact_syn": [
#             "Random decision forest"
#         ]
#     },
#     "Deformable registration": {
#         "uri": "http://edamontology.org/operation__RCPVGO34XrwrJasQ5yWBg9k",
#         "narrow_syn": [
#             "Elastic registration"
#         ]
#     },
#     "Image fusion": {
#         "uri": "http://edamontology.org/operation_____Image_fusion"
#     },
#     "Detector bias correction": {
#         "uri": "http://edamontology.org/operation__RDlueIjODveP3FyOknVAqo5",
#         "narrow_syn": [
#             "Camera bias correction"
#         ]
#     },
#     "Image crop": {
#         "uri": "http://edamontology.org/operation__Rhb4iyLUQWY4HnhPpuqNNI"
#     },
#     "Computed tomography": {
#         "uri": "http://edamontology.org/topic__RxfmHE99gOkUOOML5krfsJ",
#         "exact_syn": [
#             "CAT scan"
#         ],
#         "narrow_syn": [
#             "High-resolution micro-CT"
#         ],
#         "related_syn": [
#             "High-resolution X-ray tomography"
#         ]
#     },
#     "xml": {
#         "uri": "http://edamontology.org/format_xml",
#         "exact_syn": [
#             ".xml"
#         ]
#     },
#     "vsi": {
#         "uri": "http://edamontology.org/format_vsi",
#         "exact_syn": [
#             ".vsi"
#         ]
#     },
#     "Particle tracking": {
#         "uri": "http://edamontology.org/operation_Particle_tracking"
#     },
#     "Tissue image analysis": {
#         "uri": "http://edamontology.org/topic_Digital_histology",
#         "exact_syn": [
#             "Digital histology"
#         ],
#         "broad_syn": [
#             "Tissue image informatics"
#         ]
#     },
#     "Shape features extraction": {
#         "uri": "http://edamontology.org/operation_Shape_features",
#         "exact_syn": [
#             "Shape feature extraction"
#         ],
#         "related_syn": [
#             "Area"
#         ]
#     },
#     "Optimisation or refinement": {
#         "uri": "http://edamontology.org/operation___Optimisation_or_refinement",
#         "exact_syn": [
#             "Optimization or refinement"
#         ]
#     },
#     "Artificial neural network": {
#         "uri": "http://edamontology.org/topic______Artificial_neural_network",
#         "exact_syn": [
#             "ANN"
#         ],
#         "narrow_syn": [
#             "Dense neural network"
#         ]
#     },
#     "Cryo electron microscopy": {
#         "uri": "http://edamontology.org/topic______Cryo_electron_microscopy"
#     },
#     "In-vivo imaging": {
#         "uri": "http://edamontology.org/topic__R8XUtD89JCyeUaaVebe9Mkw"
#     },
#     "Synthetic image generation": {
#         "uri": "http://edamontology.org/operation__R9FvNkpDIaqZQhLVlPsHisj",
#         "exact_syn": [
#             "Image simulation"
#         ]
#     },
#     "sm2": {
#         "uri": "http://edamontology.org/format_sm2",
#         "exact_syn": [
#             ".sm2"
#         ]
#     },
#     "High-throughput screening": {
#         "uri": "http://edamontology.org/topic______High_throughput_screening",
#         "exact_syn": [
#             "HTS"
#         ]
#     },
#     "Contrasting method": {
#         "uri": "http://edamontology.org/topic______Contrasting"
#     },
#     "Molecular imaging": {
#         "uri": "http://edamontology.org/topic______Molecular_Imaging"
#     },
#     "Chromatic aberration correction": {
#         "uri": "http://edamontology.org/operation__RDr8xcZEa4L3mZsslmhhee8",
#         "related_syn": [
#             "Channel shift correction"
#         ]
#     },
#     "Re-scan confocal microscopy": {
#         "uri": "http://edamontology.org/topic______Re-scan_confocal_microscopy",
#         "exact_syn": [
#             "RCM"
#         ],
#         "related_syn": [
#             "Re-Scan"
#         ]
#     },
#     "Light microscopy": {
#         "uri": "http://edamontology.org/topic_3385",
#         "exact_syn": [
#             "Optical microscopy"
#         ]
#     },
#     "Super-resolution microscopy": {
#         "uri": "http://edamontology.org/topic_Super-resolution_microscopy",
#         "exact_syn": [
#             "SR microscopy"
#         ],
#         "narrow_syn": [
#             "High resolution microscopy"
#         ]
#     },
#     "Object counting": {
#         "uri": "http://edamontology.org/operation_Cell_counting"
#     },
#     "Array-based detection microscopy": {
#         "uri": "http://edamontology.org/topic__RBsSZve5PnQFO3scMDWo9f0",
#         "narrow_syn": [
#             "Area-capturing microscopy"
#         ],
#         "related_syn": [
#             "Camera based microscopy"
#         ]
#     },
#     "Data augmentation": {
#         "uri": "http://edamontology.org/operation______Data_augmentation"
#     },
#     "Object trajectory": {
#         "uri": "http://edamontology.org/data_Trajectory"
#     },
#     "csv": {
#         "uri": "http://edamontology.org/format_csv"
#     },
#     "X-ray microtomography": {
#         "uri": "http://edamontology.org/topic______Computed_microtomography",
#         "exact_syn": [
#             "\u00b5CT"
#         ]
#     },
#     "Phase-contrast microscopy": {
#         "uri": "http://edamontology.org/topic__RtBCcu7zJiS0phrbR2HzAI",
#         "narrow_syn": [
#             "Phase imaging"
#         ],
#         "related_syn": [
#             "Quantitative phase-contrast imaging"
#         ]
#     },
#     "Density-based clustering": {
#         "uri": "http://edamontology.org/operation______Density-based_clustering"
#     },
#     "Active contours": {
#         "uri": "http://edamontology.org/operation_Active_contours",
#         "exact_syn": [
#             "Active contour model"
#         ],
#         "narrow_syn": [
#             "Snakes"
#         ]
#     },
#     "Object shape": {
#         "uri": "http://edamontology.org/data__RPhipiN98zgq3wqXj4ESkT"
#     },
#     "Annotation": {
#         "uri": "http://edamontology.org/operation_0226"
#     },
#     "Focused ion beam scanning electron microscopy": {
#         "uri": "http://edamontology.org/topic__R9zg34pnGmTyzPidJj9vfJt",
#         "exact_syn": [
#             "FIBSEM"
#         ]
#     },
#     "Image validation": {
#         "uri": "http://edamontology.org/operation___Image_validation"
#     },
#     "Object classification": {
#         "uri": "http://edamontology.org/operation__RyCFuPLOeGxpcGjYbWcWWD",
#         "exact_syn": [
#             "Semantic object classification"
#         ]
#     },
#     "Cell tracking": {
#         "uri": "http://edamontology.org/operation_Cell_tracking"
#     },
#     "Ridge detection": {
#         "uri": "http://edamontology.org/operation_____Ridge_detection"
#     },
#     "Validation": {
#         "uri": "http://edamontology.org/operation___Validation"
#     },
#     "Semi-automatic segmentation": {
#         "uri": "http://edamontology.org/operation______Semi-automatic_segmentation"
#     },
#     "Photomanipulation": {
#         "uri": "http://edamontology.org/topic______Photomanipulation"
#     },
#     "Reinforcement learning": {
#         "uri": "http://edamontology.org/topic___Reinforcement_learning"
#     },
#     "Image sensor characteristics": {
#         "uri": "http://edamontology.org/data____Image_sensor_characteristics"
#     },
#     "Dilation": {
#         "uri": "http://edamontology.org/operation_Dilation",
#         "exact_syn": [
#             "Dilatation"
#         ]
#     },
#     "jpg": {
#         "uri": "http://edamontology.org/format_jpg",
#         "exact_syn": [
#             ".jpg"
#         ]
#     },
#     "Object-based colocalisation analysis": {
#         "uri": "http://edamontology.org/operation_Image_colocalization",
#         "exact_syn": [
#             "Object-based colocalization analysis"
#         ]
#     },
#     "Image classification": {
#         "uri": "http://edamontology.org/operation_Image_classification"
#     },
#     "Detector gain correction": {
#         "uri": "http://edamontology.org/operation__RCi5QWhY2hXnO46smg6bHRQ"
#     },
#     "scn": {
#         "uri": "http://edamontology.org/format_scn",
#         "exact_syn": [
#             ".scn"
#         ]
#     },
#     "X-ray imaging": {
#         "uri": "http://edamontology.org/topic______X_ray_imaging"
#     },
#     "Point-scanning microscopy": {
#         "uri": "http://edamontology.org/topic__R7Vn7GbwtqVvGWNAMGdcNW1",
#         "narrow_syn": [
#             "Scanning probe microscopy"
#         ],
#         "related_syn": [
#             "4Pi microscopy"
#         ]
#     },
#     "has topic": {
#         "uri": "http://edamontology.org/has_topic"
#     },
#     "Feature-based registration": {
#         "uri": "http://edamontology.org/operation__R9EjejimBB0tmnQRmZt0RhA",
#         "narrow_syn": [
#             "Shape-based registration"
#         ]
#     },
#     "Histology": {
#         "uri": "http://edamontology.org/topic_____Histology"
#     },
#     "Photoactivation": {
#         "uri": "http://edamontology.org/topic______Photoactivation",
#         "related_syn": [
#             "Optogenetics"
#         ]
#     },
#     "isdebtag": {
#         "uri": "http://edamontology.org/isdebtag"
#     },
#     "Morphological operation": {
#         "uri": "http://edamontology.org/operation_Morphological_operations",
#         "exact_syn": [
#             "Morphological image processing"
#         ]
#     },
#     "Image feature detection": {
#         "uri": "http://edamontology.org/operation_Object_detection",
#         "exact_syn": [
#             "Image feature extraction"
#         ]
#     },
#     "avi": {
#         "uri": "http://edamontology.org/format_avi",
#         "exact_syn": [
#             ".avi"
#         ]
#     },
#     "Slice rendering": {
#         "uri": "http://edamontology.org/operation____Slice_rendering",
#         "exact_syn": [
#             "Slice viewing"
#         ]
#     },
#     "Correlative light and electron microscopy": {
#         "uri": "http://edamontology.org/topic__R8Ss4wIFt90wZ1yjFLfXyPM",
#         "exact_syn": [
#             "Correlative light-electron microscopy"
#         ],
#         "narrow_syn": [
#             "Integrated light and electron microscopy (ILEM)"
#         ]
#     },
#     "Stimulated emission depletion microscopy": {
#         "uri": "http://edamontology.org/topic__RMCSMqSNvOTurvW2FV8tjN",
#         "exact_syn": [
#             "STED"
#         ],
#         "narrow_syn": [
#             "Reversible saturable optical linear fluorescence transitions microscopy (RESOLFT)"
#         ],
#         "broad_syn": [
#             "STED-4Pi"
#         ]
#     },
#     "Electron tomography": {
#         "uri": "http://edamontology.org/topic__R9O3HmIAjoN5IqXXXRukzzr",
#         "related_syn": [
#             "Electron Microscopy Array Tomography"
#         ]
#     },
#     "Autoencoder": {
#         "uri": "http://edamontology.org/topic______Autoencoder",
#         "exact_syn": [
#             "Autoencoder network"
#         ]
#     },
#     "Image denoising": {
#         "uri": "http://edamontology.org/operation__RDyyXyhf1oHK93opXhEnRND",
#         "exact_syn": [
#             "Noise reduction"
#         ]
#     },
#     "Data generation": {
#         "uri": "http://edamontology.org/operation_3429",
#         "exact_syn": [
#             "Data synthesis"
#         ]
#     },
#     "Related term": {
#         "uri": "http://edamontology.org/related_term"
#     },
#     "has format": {
#         "uri": "http://edamontology.org/has_format"
#     },
#     "Data": {
#         "uri": "http://edamontology.org/data_0006",
#         "exact_syn": [
#             "Data record"
#         ],
#         "narrow_syn": [
#             "Data set"
#         ]
#     },
#     "Image histogram": {
#         "uri": "http://edamontology.org/data_Image_histogram"
#     },
#     "Cell segmentation": {
#         "uri": "http://edamontology.org/operation_Cell_segmentation"
#     },
#     "Image deconvolution": {
#         "uri": "http://edamontology.org/operation_Image_deconvolution"
#     },
#     "Ratiometric imaging": {
#         "uri": "http://edamontology.org/topic______Ratiometric_imaging"
#     },
#     "Structured illumination reconstruction": {
#         "uri": "http://edamontology.org/operation__R8V95OnTjs7fCvVXWjaXrh6"
#     },
#     "Erosion": {
#         "uri": "http://edamontology.org/operation_Erosion"
#     },
#     "Topic": {
#         "uri": "http://edamontology.org/topic_0003",
#         "related_syn": [
#             "sumo:FieldOfStudy"
#         ]
#     },
#     "Image-to-image translation": {
#         "uri": "http://edamontology.org/operation______Image-to-image_translation",
#         "narrow_syn": [
#             "Neural style transfer"
#         ]
#     },
#     "Linear transformation": {
#         "uri": "http://edamontology.org/operation_Linear_transformation",
#         "narrow_syn": [
#             "Image resampling"
#         ]
#     },
#     "File extension": {
#         "uri": "http://edamontology.org/file_extension"
#     },
#     "Widefield fluorescence microscopy": {
#         "uri": "http://edamontology.org/topic_Widefield_microscopy",
#         "narrow_syn": [
#             "Epi-fluorescence microscopy"
#         ]
#     },
#     "Microscopy": {
#         "uri": "http://edamontology.org/topic_Microscopy",
#         "narrow_syn": [
#             "Slide scanner"
#         ]
#     },
#     "Imaging": {
#         "uri": "http://edamontology.org/topic_3382"
#     },
#     "Image projection": {
#         "uri": "http://edamontology.org/operation_Projection",
#         "exact_syn": [
#             "Maximum projection"
#         ],
#         "narrow_syn": [
#             "Maximum intensity projection"
#         ]
#     },
#     "Phase-contrast X-ray imaging": {
#         "uri": "http://edamontology.org/topic______Phase_Contrast_X-Ray_Imaging",
#         "exact_syn": [
#             "PCI"
#         ]
#     },
#     "Bioimage informatics": {
#         "uri": "http://edamontology.org/topic__RBDp7HwdUBEjpS6PRjYfV2V",
#         "narrow_syn": [
#             "Bioimage analysis"
#         ]
#     },
#     "Velocity extraction": {
#         "uri": "http://edamontology.org/operation_____Velocity_extraction"
#     },
#     "High-content analysis": {
#         "uri": "http://edamontology.org/topic_High_content_screening",
#         "exact_syn": [
#             "HCA"
#         ],
#         "narrow_syn": [
#             "High-content screening (HCS)"
#         ]
#     },
#     "Unsupervised learning": {
#         "uri": "http://edamontology.org/topic___Unsupervised_learning"
#     },
#     "Spectral properties": {
#         "uri": "http://edamontology.org/data__RCDMkOl5gzD23OFsPf6vr4a"
#     },
#     "Radial basis function network": {
#         "uri": "http://edamontology.org/topic______Radial_basis_function_network",
#         "exact_syn": [
#             "RBF network"
#         ]
#     },
#     "Colocalisation analysis": {
#         "uri": "http://edamontology.org/operation___Colocalisation_analysis",
#         "exact_syn": [
#             "Co-localization analysis"
#         ]
#     },
#     "Polarized light microscopy": {
#         "uri": "http://edamontology.org/topic__R8nlu8VCuL5nvBFgOaGNHgT"
#     },
#     "Region of interest": {
#         "uri": "http://edamontology.org/data_Roi",
#         "exact_syn": [
#             "ROI"
#         ]
#     },
#     "ism": {
#         "uri": "http://edamontology.org/format_ism"
#     },
#     "mpeg": {
#         "uri": "http://edamontology.org/format_mpeg"
#     },
#     "Multi-channel image": {
#         "uri": "http://edamontology.org/data__R0uFIvsA9tQJYZz8NM3Smk"
#     },
#     "Object characteristics": {
#         "uri": "http://edamontology.org/data__Rj7rpnkJ6SPPwWkQ4x3Wik",
#         "exact_syn": [
#             "Object feature"
#         ],
#         "narrow_syn": [
#             "Object measurement"
#         ],
#         "broad_syn": [
#             "Object data"
#         ]
#     },
#     "Quantitative phase imaging": {
#         "uri": "http://edamontology.org/topic______Quantitative_phase_imaging"
#     },
#     "Anaglyph": {
#         "uri": "http://edamontology.org/operation_Anaglyph"
#     },
#     "has input": {
#         "uri": "http://edamontology.org/has_input",
#         "related_syn": [
#             "OBO_REL:has_participant"
#         ]
#     },
#     "Non-linear microscopy": {
#         "uri": "http://edamontology.org/topic_____Non-linear_microscopy"
#     },
#     "3D image": {
#         "uri": "http://edamontology.org/data_3D_dataset",
#         "related_syn": [
#             "Image stack"
#         ]
#     },
#     "Single particle cryo-electron microscopy": {
#         "uri": "http://edamontology.org/topic______Single_Particle_Cryo-Electron_microscopy",
#         "narrow_syn": [
#             "SPA"
#         ]
#     },
#     "Nuclear magnetic resonance spectroscopy": {
#         "uri": "http://edamontology.org/topic_0593",
#         "exact_syn": [
#             "NMR"
#         ],
#         "narrow_syn": [
#             "Magnetic resonance spectroscopy (MRS)"
#         ]
#     },
#     "Data handling": {
#         "uri": "http://edamontology.org/operation_2409"
#     },
#     "Data sharing": {
#         "uri": "http://edamontology.org/topic__RwTXNChEQ9hv7IpvHjQGin"
#     },
#     "Visualisation": {
#         "uri": "http://edamontology.org/operation_0337",
#         "narrow_syn": [
#             "Plotting"
#         ]
#     },
#     "Stereology": {
#         "uri": "http://edamontology.org/topic______Stereology"
#     },
#     "Contrast enhancement": {
#         "uri": "http://edamontology.org/operation____Contrast_enhancement"
#     },
#     "Deconvolution widefield microscopy": {
#         "uri": "http://edamontology.org/topic______Deconvolution_widefield_microscopy"
#     },
#     "is input of": {
#         "uri": "http://edamontology.org/is_input_of",
#         "related_syn": [
#             "OBO_REL:participates_in"
#         ]
#     },
#     "sm3": {
#         "uri": "http://edamontology.org/format_sm3",
#         "exact_syn": [
#             ".sm3"
#         ]
#     },
#     "Adaptive thresholding": {
#         "uri": "http://edamontology.org/operation_Adaptative_thresholding",
#         "exact_syn": [
#             "Local thresholding"
#         ]
#     },
#     "is function of": {
#         "uri": "http://edamontology.org/is_function_of",
#         "narrow_syn": [
#             "OBO_REL:function_of"
#         ],
#         "related_syn": [
#             "OBO_REL:inheres_in"
#         ]
#     },
#     "Citation": {
#         "uri": "http://edamontology.org/citation",
#         "broad_syn": [
#             "Publication reference"
#         ],
#         "related_syn": [
#             "Publication"
#         ]
#     },
#     "Electron microscopy": {
#         "uri": "http://edamontology.org/topic_0611",
#         "exact_syn": [
#             "EM"
#         ]
#     },
#     "txt": {
#         "uri": "http://edamontology.org/format_txt",
#         "exact_syn": [
#             ".txt"
#         ]
#     },
#     "Spectral unmixing": {
#         "uri": "http://edamontology.org/operation__R7qn3VpJyCAPGqdW6ia3h2d",
#         "related_syn": [
#             "Color deconvolution"
#         ]
#     },
#     "Hierarchical clustering": {
#         "uri": "http://edamontology.org/operation______Connectivity-based_clustering",
#         "exact_syn": [
#             "Connectivity-based clustering"
#         ]
#     },
#     "Bayesian network": {
#         "uri": "http://edamontology.org/topic______Bayesian_network"
#     },
#     "Semi-supervised learning": {
#         "uri": "http://edamontology.org/topic______Semi-supervised_learning"
#     },
#     "Drift correction": {
#         "uri": "http://edamontology.org/operation__RBh3vNecu5XlIPh3kbMM4Cq"
#     },
#     "Unstained sample": {
#         "uri": "http://edamontology.org/topic______Unstained_sample",
#         "exact_syn": [
#             "Label-free sample"
#         ]
#     },
#     "Overlap analysis": {
#         "uri": "http://edamontology.org/operation_____Overlap_analysis",
#         "exact_syn": [
#             "Intersection analysis"
#         ]
#     },
#     "Total internal reflection fluorescence microscopy": {
#         "uri": "http://edamontology.org/topic_____Total_internal_reflection_fluorescence_microscopy",
#         "exact_syn": [
#             "TIRF"
#         ],
#         "related_syn": [
#             "highly inclined and laminated optical sheet (HiLo)"
#         ]
#     },
#     "Blotting": {
#         "uri": "http://edamontology.org/topic______Blotting"
#     },
#     "Spectroscopy": {
#         "uri": "http://edamontology.org/topic__RBfI2XgIsxcfKonPPluKAhK",
#         "narrow_syn": [
#             "Spectrometry"
#         ]
#     },
#     "Recurrent neural network": {
#         "uri": "http://edamontology.org/topic______Recurrent_neural_network",
#         "exact_syn": [
#             "RNN"
#         ]
#     },
#     "Opening": {
#         "uri": "http://edamontology.org/operation_Opening"
#     },
#     "Single molecule localisation microscopy": {
#         "uri": "http://edamontology.org/topic__R8oQpUEjKZjNQCTB4x3JQuJ",
#         "exact_syn": [
#             "Single molecule localization microscopy"
#         ],
#         "narrow_syn": [
#             "Ground state depletion individual molecule return (GSDIM)"
#         ]
#     },
#     "Interferometric microscopy": {
#         "uri": "http://edamontology.org/topic_____Interferometric_microscopy",
#         "narrow_syn": [
#             "Interference reflection microscopy"
#         ]
#     },
#     "Transmission electron microscopy": {
#         "uri": "http://edamontology.org/topic__R7LElbFkBgKS401YKsVtNck",
#         "exact_syn": [
#             "TEM"
#         ]
#     },
#     "Image thresholding": {
#         "uri": "http://edamontology.org/operation_Image_thresholding",
#         "exact_syn": [
#             "Thresholding"
#         ],
#         "narrow_syn": [
#             "Clustering-based image thresholding"
#         ]
#     },
#     "Image correlation spectroscopy": {
#         "uri": "http://edamontology.org/topic___Image_correlation_spectroscopy",
#         "exact_syn": [
#             "ICS"
#         ],
#         "related_syn": [
#             "Particle Image Correlation Spectroscopy (PICS)"
#         ]
#     },
#     "raw": {
#         "uri": "http://edamontology.org/format_raw",
#         "exact_syn": [
#             ".raw"
#         ]
#     },
#     "Filament tracing": {
#         "uri": "http://edamontology.org/operation__R9Qf06vxvFj2UbAk7pW3IMG",
#         "exact_syn": [
#             "Tubular structure extraction"
#         ],
#         "narrow_syn": [
#             "Biofilament tracing"
#         ],
#         "related_syn": [
#             "Curvilinear structure reconstruction"
#         ]
#     },
#     "Mass spectrometry imaging": {
#         "uri": "http://edamontology.org/topic_____Mass_spectrometry_imaging",
#         "exact_syn": [
#             "MSI"
#         ],
#         "related_syn": [
#             "Matrix-assisted laser desorption ionization imaging"
#         ]
#     },
#     "Cell image analysis": {
#         "uri": "http://edamontology.org/topic_____Cell_image_analysis",
#         "exact_syn": [
#             "Digital cytology"
#         ],
#         "broad_syn": [
#             "Cell image informatics"
#         ]
#     },
#     "F\u00f6rster resonance energy transfer": {
#         "uri": "http://edamontology.org/topic___Foerster_resonance_energy_transfer",
#         "exact_syn": [
#             "Fluorescence resonance energy transfer"
#         ]
#     },
#     "Plotting": {
#         "uri": "http://edamontology.org/operation_3441"
#     },
#     "Scanning electron cryomicroscopy": {
#         "uri": "http://edamontology.org/topic__RBNfUSYBOKUapWrsyPMMTkw",
#         "exact_syn": [
#             "Cryo-scanning electron microscopy"
#         ]
#     },
#     "Classification": {
#         "uri": "http://edamontology.org/operation_2990"
#     },
#     "Convolutional neural network": {
#         "uri": "http://edamontology.org/topic______Convolutional_neural_network",
#         "exact_syn": [
#             "ConvNet"
#         ]
#     },
#     "Affine transformation": {
#         "uri": "http://edamontology.org/operation__R8ANfLkuHu47r739AkhxrId",
#         "related_syn": [
#             "Orthographic projection"
#         ]
#     },
#     "tiff": {
#         "uri": "http://edamontology.org/format_tiff",
#         "exact_syn": [
#             ".tiff"
#         ]
#     },
#     "is topic of": {
#         "uri": "http://edamontology.org/is_topic_of",
#         "related_syn": [
#             "OBO_REL:quality_of"
#         ]
#     },
#     "Magnetic resonance imaging": {
#         "uri": "http://edamontology.org/topic_3444",
#         "exact_syn": [
#             "MRI"
#         ]
#     },
#     "Deep learning": {
#         "uri": "http://edamontology.org/topic______Deep_learning"
#     },
#     "Time": {
#         "uri": "http://edamontology.org/data_Time"
#     },
#     "High-pressure freezing": {
#         "uri": "http://edamontology.org/topic__RkSYwMcVWG5FCi4BaWDMaJ"
#     },
#     "Image visualisation": {
#         "uri": "http://edamontology.org/operation_Image_visualisation",
#         "exact_syn": [
#             "Rendering"
#         ],
#         "narrow_syn": [
#             "Lookup table"
#         ]
#     },
#     "Homogeneity extraction": {
#         "uri": "http://edamontology.org/operation_Homogeneity"
#     },
#     "Example": {
#         "uri": "http://edamontology.org/example"
#     },
#     "ims": {
#         "uri": "http://edamontology.org/format_ims",
#         "exact_syn": [
#             ".ims"
#         ]
#     },
#     "Regression": {
#         "uri": "http://edamontology.org/operation_2423"
#     },
#     "Isolated object tracking": {
#         "uri": "http://edamontology.org/operation__RDsrmC9l0bZw9kGJzGMCyY8"
#     },
#     "Point spread function": {
#         "uri": "http://edamontology.org/data____Point_spread_function",
#         "exact_syn": [
#             "PSF"
#         ]
#     },
#     "Structured illumination microscopy": {
#         "uri": "http://edamontology.org/topic__RC91JqkkQnsmvg8zuG6Td7q",
#         "exact_syn": [
#             "SIM"
#         ],
#         "related_syn": [
#             "iSIM"
#         ]
#     },
#     "tif": {
#         "uri": "http://edamontology.org/format_tif"
#     },
#     "In-vitro imaging": {
#         "uri": "http://edamontology.org/topic__R7WRbf9Y8ySw9QWPwAjzcUa"
#     },
#     "Near-field scanning optical microscopy": {
#         "uri": "http://edamontology.org/topic_____Near-field_scanning_optical_microscopy",
#         "exact_syn": [
#             "NSOM"
#         ],
#         "narrow_syn": [
#             "Scattering-type scanning near-field optical microscopy"
#         ]
#     },
#     "Spot detection": {
#         "uri": "http://edamontology.org/operation_Spot_extraction",
#         "narrow_syn": [
#             "Seed point detection"
#         ]
#     },
#     "Format": {
#         "uri": "http://edamontology.org/format_1915",
#         "narrow_syn": [
#             "File format"
#         ],
#         "broad_syn": [
#             "Data model"
#         ]
#     },
#     "has identifier": {
#         "uri": "http://edamontology.org/has_identifier"
#     },
#     "Machine learning-based data generation": {
#         "uri": "http://edamontology.org/operation______Machine_learning-based_data_generation"
#     },
#     "Image scanning microscopy": {
#         "uri": "http://edamontology.org/topic______Image_Scanning_Microscopy",
#         "exact_syn": [
#             "ISM"
#         ]
#     },
#     "Region texture": {
#         "uri": "http://edamontology.org/data__RDz7WLs6GBWl7rPjqfjKBT0"
#     },
#     "Ablation": {
#         "uri": "http://edamontology.org/topic______Ablation",
#         "narrow_syn": [
#             "FIB"
#         ]
#     },
#     "Image radiometric noise characteristics": {
#         "uri": "http://edamontology.org/data__R7Vdp7H5PzNJiqA7JaEEPrJ"
#     },
#     "Sample immobilisation": {
#         "uri": "http://edamontology.org/topic______Sample_fixation",
#         "exact_syn": [
#             "Sample fixation"
#         ]
#     },
#     "Sample staining": {
#         "uri": "http://edamontology.org/topic______Staining"
#     },
#     "Skeletonisation": {
#         "uri": "http://edamontology.org/operation_Skeletonization",
#         "narrow_syn": [
#             "Medial axis transform"
#         ]
#     },
#     "Pattern recognition": {
#         "uri": "http://edamontology.org/operation__RDetoixS3xEu0agR2CebaoB"
#     },
#     "Selective plane illumination microscopy reconstruction": {
#         "uri": "http://edamontology.org/operation__RBPObKBKIMwjdLygBOlvojW"
#     },
#     "Image radiometric noise": {
#         "uri": "http://edamontology.org/data__RDr5D5pOVdnB8hASL1LG8HH"
#     },
#     "Image formation characteristics": {
#         "uri": "http://edamontology.org/data____Image_formation_characteristics"
#     },
#     "Fluctuation based microscopy": {
#         "uri": "http://edamontology.org/topic___Fluctuation_based_microscopy",
#         "narrow_syn": [
#             "Super resolution radial fluctuations (SRRF)"
#         ]
#     },
#     "Obsolete since": {
#         "uri": "http://edamontology.org/obsolete_since"
#     },
#     "Scanning electron microscopy": {
#         "uri": "http://edamontology.org/topic__RBZsLMTdyuEDtVe2fge61l0",
#         "exact_syn": [
#             "SEM"
#         ]
#     },
#     "Image": {
#         "uri": "http://edamontology.org/data_Image",
#         "exact_syn": [
#             "Image data"
#         ],
#         "narrow_syn": [
#             "Voxel-based image"
#         ]
#     },
#     "Intensity": {
#         "uri": "http://edamontology.org/data_Intensity"
#     },
#     "Top-hat transform": {
#         "uri": "http://edamontology.org/operation____Top-hat_transform",
#         "exact_syn": [
#             "White top-hat transform"
#         ],
#         "broad_syn": [
#             "Hat transform"
#         ],
#         "related_syn": [
#             "Black top-hat transform"
#         ]
#     },
#     "Near-infrared branding": {
#         "uri": "http://edamontology.org/topic_____Near-infrared_branding"
#     },
#     "Optical coherence tomography": {
#         "uri": "http://edamontology.org/topic______Optical_Coherence_Tomography",
#         "exact_syn": [
#             "OCT"
#         ]
#     },
#     "Image convolution": {
#         "uri": "http://edamontology.org/operation___Image_convolution",
#         "exact_syn": [
#             "Linear shift invariant image filtering"
#         ]
#     },
#     "Traction force microscopy": {
#         "uri": "http://edamontology.org/topic_____Traction_force_microscopy"
#     },
#     "Rotation": {
#         "uri": "http://edamontology.org/operation_Rotation"
#     },
#     "Parameter optimisation": {
#         "uri": "http://edamontology.org/operation___Parameter_optimisation",
#         "exact_syn": [
#             "Parameter optimization"
#         ]
#     },
#     "Positron emission tomography": {
#         "uri": "http://edamontology.org/topic__RDos3h5yRfjhLUcOImDOFgB",
#         "narrow_syn": [
#             "PET"
#         ]
#     },
#     "Distance transform": {
#         "uri": "http://edamontology.org/operation_Distance_transform"
#     },
#     "Scanning transmission electron microscopy": {
#         "uri": "http://edamontology.org/topic__RXLeVr0cHSXzTSRyO5zwZD",
#         "exact_syn": [
#             "STEM"
#         ]
#     },
#     "Fluorescence microscopy": {
#         "uri": "http://edamontology.org/topic_Fluorescent_microscopy"
#     },
#     "1D image": {
#         "uri": "http://edamontology.org/data_1D_dataset"
#     },
#     "Region growing": {
#         "uri": "http://edamontology.org/operation____Region_growing",
#         "broad_syn": [
#             "Region-based segmentation"
#         ]
#     },
#     "Image stitching": {
#         "uri": "http://edamontology.org/operation_Image_stitching",
#         "related_syn": [
#             "Mosaic"
#         ]
#     },
#     "Surface rendering": {
#         "uri": "http://edamontology.org/operation____Surface_rendering"
#     },
#     "Illumination correction": {
#         "uri": "http://edamontology.org/operation_Illumination_correction",
#         "exact_syn": [
#             "Flat field correction"
#         ]
#     },
#     "Fixed sample imaging": {
#         "uri": "http://edamontology.org/topic__RBNoPZIOvBhdWGe8mFNpoWQ"
#     },
#     "Photonic force microscopy": {
#         "uri": "http://edamontology.org/topic_____Photon_force_microscopy",
#         "exact_syn": [
#             "PFM"
#         ],
#         "narrow_syn": [
#             "Force sensing optical tweezers"
#         ]
#     },
#     "Colour": {
#         "uri": "http://edamontology.org/data_Colour",
#         "narrow_syn": [
#             "rgb"
#         ]
#     },
#     "Optical transfer function": {
#         "uri": "http://edamontology.org/data____Optical_transfer_function",
#         "exact_syn": [
#             "OTF"
#         ]
#     },
#     "Spatial properties": {
#         "uri": "http://edamontology.org/data__R7Xr4YLUfGpHoI3FnAzgMnA"
#     },
#     "Second-harmonic imaging microscopy": {
#         "uri": "http://edamontology.org/topic_____Second-harmonic_imaging_microscopy",
#         "exact_syn": [
#             "SHIM"
#         ],
#         "narrow_syn": [
#             "Third harmonic generation (THG)"
#         ]
#     },
#     "Centroid-based clustering": {
#         "uri": "http://edamontology.org/operation______Centroid-based_clustering"
#     },
#     "Statistics": {
#         "uri": "http://edamontology.org/topic_Statistics"
#     },
#     "Multimodal imaging": {
#         "uri": "http://edamontology.org/topic____Multimodal_imaging",
#         "exact_syn": [
#             "Multisensor imaging"
#         ],
#         "narrow_syn": [
#             "Correlative imaging"
#         ]
#     },
#     "hdr": {
#         "uri": "http://edamontology.org/format_hdr",
#         "exact_syn": [
#             ".hdr"
#         ]
#     },
#     "Raman imaging": {
#         "uri": "http://edamontology.org/topic_____Raman_imaging",
#         "related_syn": [
#             "Coherent anti-Stokes Raman scattering microscopy (CARS)"
#         ]
#     },
#     "Computer vision": {
#         "uri": "http://edamontology.org/topic______Computer_vision"
#     },
#     "Fluorescence": {
#         "uri": "http://edamontology.org/topic______Fluorescence"
#     },
#     "Spatial coordinates": {
#         "uri": "http://edamontology.org/data____Spatial_coordinates"
#     },
#     "Fluorescence correlation spectroscopy": {
#         "uri": "http://edamontology.org/topic___Fluorescence_correlative_spectroscopy",
#         "exact_syn": [
#             "FCS"
#         ],
#         "related_syn": [
#             "Fluorescence cross-correlation spectroscopy (FCCS)"
#         ]
#     },
#     "Watershed segmentation": {
#         "uri": "http://edamontology.org/operation_Watershed",
#         "exact_syn": [
#             "Watershed-based segmentation"
#         ],
#         "broad_syn": [
#             "Watershed transformation"
#         ]
#     },
#     "Chemical fixation": {
#         "uri": "http://edamontology.org/topic______Chemical_fixation"
#     },
#     "Closing": {
#         "uri": "http://edamontology.org/operation_Closing"
#     },
#     "Confocal microscopy": {
#         "uri": "http://edamontology.org/topic__R9Cmje2ZUXyDW6aQAvFhwSM",
#         "exact_syn": [
#             "Confocal laser scanning microscopy (CLSM)"
#         ]
#     },
#     "Image data": {
#         "uri": "http://edamontology.org/data__RCOwaNKaK3gFcUhkjBq7aor",
#         "exact_syn": [
#             "Image"
#         ]
#     },
#     "Spectral image resolution": {
#         "uri": "http://edamontology.org/data__RDLZjniM2p9bxNi1Md2Vqv3"
#     },
#     "Clustering": {
#         "uri": "http://edamontology.org/operation___Clustering",
#         "exact_syn": [
#             "Cluster analysis"
#         ]
#     },
#     "stk": {
#         "uri": "http://edamontology.org/format_stk",
#         "exact_syn": [
#             ".stk"
#         ]
#     },
#     "Frequency-domain transformation": {
#         "uri": "http://edamontology.org/operation_____Frequency_domain",
#         "exact_syn": [
#             "Transformation into frequency domain"
#         ],
#         "related_syn": [
#             "Fast Fourier transform"
#         ]
#     },
#     "Optical flow analysis": {
#         "uri": "http://edamontology.org/operation_Optical_flow_analysis"
#     },
#     "Force microscopy": {
#         "uri": "http://edamontology.org/topic_____Force_microscopy"
#     },
#     "Rigid registration": {
#         "uri": "http://edamontology.org/operation__R9Vc5BV3ZMcLHEL6WEceXbY",
#         "exact_syn": [
#             "Rigid image registration"
#         ]
#     },
#     "Object velocity": {
#         "uri": "http://edamontology.org/data__R9P4sScuriz9yN8l827hrLo",
#         "exact_syn": [
#             "Object speed"
#         ]
#     },
#     "Instrument response function": {
#         "uri": "http://edamontology.org/data____Instrument_response_function",
#         "exact_syn": [
#             "IRF"
#         ]
#     },
#     "Instrument maintenance": {
#         "uri": "http://edamontology.org/topic______Instrument_maintenance",
#         "narrow_syn": [
#             "Instrument calibration"
#         ],
#         "related_syn": [
#             "Instrument setup"
#         ]
#     }
# }

# %% [markdown]
# # 3. Compute syntactic distance between a set of tags and synonyms
# the distance is is a floating number between 0 and 1. The weighted distance, not very meaningfull, is a weighted mean between distance considering this order of priority : label >> exact synonym >> narrow synonym >> broad synonym >> related synonym.

# %%
import jellyfish


#tags = ['Filament track']
tags = ['Fourier transformation']

#iterate over tags
for t in tags:
    distances = [] 
    
    #iterate over edam concepts and their synonyms
    for k,v in edam_syn_index.items():
        dist_es = []
        dist_rs = []
        dist_ns = []
        dist_bs = []
        #print(v)
        #print(v.keys())
        #print(f"computing distance between <{t}> and <{k}>")
        #print(jellyfish.jaro_winkler(t,k))
        
        # distance with the concept label
        d_label = jellyfish.jaro_winkler(t,k)
        
        # distance with all of the concept exact synonyms
        if 'exact_syn' in v.keys():
            for exact in v['exact_syn']:
                dist_es.append(jellyfish.jaro_winkler(t,exact))
                
        # distance with all of the concept narrow synonyms
        if 'narrow_syn' in v.keys():
            for narrow in v['narrow_syn']:
                dist_ns.append(jellyfish.jaro_winkler(t,narrow))
                
        # distance with all of the concept broad synonyms
        if 'broad_syn' in v.keys():
            for broad in v['broad_syn']:
                dist_bs.append(jellyfish.jaro_winkler(t,broad))
                
        # distance with all of the concept related synonyms
        if 'related_syn' in v.keys():
            for related in v['related_syn']:
                #print(f"distance betwen {t} and {exact}")
                dist_rs.append(jellyfish.jaro_winkler(t,related))
        
        d_es, d_ns, d_bs, d_rs = [0,0,0,0]
        
        # for each kind of synonym we peak only the closest one
        if len(dist_es) > 0:
            d_es = sorted(dist_es, reverse=True)[0]
        if len(dist_ns) > 0:
            d_ns = sorted(dist_ns, reverse=True)[0]
        if len(dist_bs) > 0:
            d_bs = sorted(dist_bs, reverse=True)[0]
        if len(dist_rs) > 0:
            d_rs = sorted(dist_rs, reverse=True)[0]
        
        # we compute a weighted distance to consider all kinds of synonyms
        weighted_d = ((10 * d_label) + (8 * d_es) + (5 * d_ns) + (3 * d_bs) + (1 * d_rs)) / (10 + 8 + 5 + 3 + 1)
        #print(f"weighted dist({t},{k}) = {weighted_d}")
        #print(f"exact dist({t},{k}) = {d_es}")
        #print(f"narrow dist({t},{k}) = {d_ns}")
        #print(f"broad dist({t},{k}) = {d_bs}")
        #print(f"related dist({t},{k}) = {d_rs}")
        distances.append({'tag': t, 'edam_concept': k, 'edam_concept_uri': v['uri'], 
                         'weighted_distance': weighted_d, 
                          'label_distance': d_label,
                         'exact_distance': d_es,
                         'narrow_distance': d_ns, 
                         'broad_distance': d_bs, 
                         'related_distance': d_rs})
    
    # after having screened all EDAM concepts, we print the top-5 suggestions. 
    print(f'****** {t} ******')
              
    print("top-5 closest concept (based on labels)")
    for c in sorted(distances, key = lambda x : (x['label_distance']), reverse=True)[0:5]:
        print(f"\t{c['edam_concept']}: {c['edam_concept_uri']} (d={c['label_distance']})")
    print()
              
    print("top-5 closest concept (based on exact synonyms)")
    for c in sorted(distances, key = lambda x : (x['exact_distance']), reverse=True)[0:5]:
        print(f"\t{c['edam_concept']}: {c['edam_concept_uri']} (d={c['exact_distance']})")
    print()
              
    print("top-5 closest concept (based on narrow synonyms)")
    for c in sorted(distances, key = lambda x : (x['narrow_distance']), reverse=True)[0:5]:
        print(f"\t{c['edam_concept']}: {c['edam_concept_uri']} (d={c['narrow_distance']})")
    print()
              
    print("top-5 closest concept (based on broad synonyms)")
    for c in sorted(distances, key = lambda x : (x['broad_distance']), reverse=True)[0:5]:
        print(f"\t{c['edam_concept']}: {c['edam_concept_uri']} (d={c['broad_distance']})")
    print()
              
    print("top-5 closest concept (based on related synonyms)")
    for c in sorted(distances, key = lambda x : (x['related_distance']), reverse=True)[0:5]:
        print(f"\t{c['edam_concept']}: {c['edam_concept_uri']} (d={c['related_distance']})")
    print()
              
    print("top-5 closest concept (based on weighted synonyms)")
    for c in sorted(distances, key = lambda x : (x['weighted_distance']), reverse=True)[0:5]:
        print(f"\t{c['edam_concept']}: {c['edam_concept_uri']} (d={c['weighted_distance']})")
    print()
    print()
# Out:
# ****** Fourier transformation ******
# top-5 closest concept (based on labels)
# 	Fourier-transform infrared spectroscopy: http://edamontology.org/topic______Fourier-transform_infrared_spectroscopy (d=0.8491841491841492)
# 	Linear transformation: http://edamontology.org/operation_Linear_transformation (d=0.7991822991822991)
# 	Affine transformation: http://edamontology.org/operation__R8ANfLkuHu47r739AkhxrId (d=0.7823189882013412)
# 	Frequency-domain transformation: http://edamontology.org/operation_____Frequency_domain (d=0.7467322999581063)
# 	Geometrical transformation: http://edamontology.org/operation_Geometrical_transform (d=0.7244509876088824)
#
# top-5 closest concept (based on exact synonyms)
# 	Image processing: http://edamontology.org/operation_Image_processing (d=0.7799242424242424)
# 	Affine registration: http://edamontology.org/operation__RLtOI0poPsYRHzgXbAcr2E (d=0.6849242424242424)
# 	Frequency-domain transformation: http://edamontology.org/operation_____Frequency_domain (d=0.6567871699450647)
# 	Filament tracing: http://edamontology.org/operation__R9Qf06vxvFj2UbAk7pW3IMG (d=0.6502886002886002)
# 	Tomographic reconstruction: http://edamontology.org/operation__R1NVO6hpWWcs99UiEFiOfK (d=0.6494949494949495)
#
# top-5 closest concept (based on narrow synonyms)
# 	Single molecule localisation: http://edamontology.org/operation__R8EfungVXA0oQM2Ac7YY5eu (d=0.6862470862470863)
# 	Instrument maintenance: http://edamontology.org/topic______Instrument_maintenance (d=0.6723484848484849)
# 	Ultrasonography: http://edamontology.org/topic__RBHw300pzIYcttGsAmIZvk5 (d=0.6684796684796686)
# 	Fluctuation based microscopy: http://edamontology.org/topic___Fluctuation_based_microscopy (d=0.6632357850228107)
# 	Image correction: http://edamontology.org/operation__R7MFwdgojfmkZ07yWbdcda0 (d=0.6612340510366826)
#
# top-5 closest concept (based on broad synonyms)
# 	Neuron image analysis: http://edamontology.org/topic_Neuron_image_analysis (d=0.6897653000594177)
# 	Watershed segmentation: http://edamontology.org/operation_Watershed (d=0.6897653000594177)
# 	In-silico reconstruction: http://edamontology.org/topic__R96toeNl9iMp8oqv9augU84 (d=0.6313588372411901)
# 	Plant image analysis: http://edamontology.org/topic_____Plant_image_analysis (d=0.6224418093983312)
# 	Region growing: http://edamontology.org/operation____Region_growing (d=0.613073593073593)
#
# top-5 closest concept (based on related synonyms)
# 	Frequency-domain transformation: http://edamontology.org/operation_____Frequency_domain (d=0.7760765550239235)
# 	Chromatic aberration correction: http://edamontology.org/operation__RDr8xcZEa4L3mZsslmhhee8 (d=0.6578282828282828)
# 	Frequency-domain analysis: http://edamontology.org/operation__RBYLqCqN4rP7Jy5m5mxpTeM (d=0.6569998628822158)
# 	Localisation markers: http://edamontology.org/topic_____Fiducial_markers (d=0.6456228956228957)
# 	Computed tomography: http://edamontology.org/topic__RxfmHE99gOkUOOML5krfsJ (d=0.6454124579124579)
#
# top-5 closest concept (based on weighted synonyms)
# 	Filament tracing: http://edamontology.org/operation__R9Qf06vxvFj2UbAk7pW3IMG (d=0.5886006388299703)
# 	Tomographic reconstruction: http://edamontology.org/operation__R1NVO6hpWWcs99UiEFiOfK (d=0.5652234596679041)
# 	Single molecule localisation: http://edamontology.org/operation__R8EfungVXA0oQM2Ac7YY5eu (d=0.5271950271950272)
# 	Scientific visualisation: http://edamontology.org/topic______Scientific_visualisation (d=0.5197367789960383)
# 	Multimodal imaging: http://edamontology.org/topic____Multimodal_imaging (d=0.5167927336543321)
